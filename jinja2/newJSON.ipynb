# %%
#!/usr/bin/env python3
# pip install pandas
# pip install requests
# pip install numpy
# pip install seaborn
# pip install matplotlib
# pip install nbconvert
# pip install reliability
# pip install rpy2
# pip install ipysheet
# pip install tabulate
import os
from IPython.display import HTML, display, JSON, clear_output
import tabulate
from cmath import nan
import jinja2
import os
import pandas as pd
import requests
import json
import py7zr
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import time
import datetime
from itertools import groupby
import numpy
from scipy.stats import pearsonr
import pickle
import _pickle as cPickle
from decimal import *
import matplotlib.pyplot as plt
import seaborn as sns
import arabic_reshaper
# install: pip install python-bidi
from bidi.algorithm import get_display
from PIL import ImageFont
from PIL import Image
from PIL import ImageDraw
from scipy.stats import fisher_exact

from statsmodels.graphics.mosaicplot import mosaic

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score, recall_score, precision_score, average_precision_score, f1_score, classification_report, accuracy_score, plot_roc_curve, plot_precision_recall_curve, plot_confusion_matrix
# %matplotlib inline
# session = requests.Session()
# retry = Retry(connect=3, backoff_factor=0.5)
# adapter = HTTPAdapter(max_retries=retry)
# session.mount('http://', adapter)
# session.mount('https://', adapter)

# %% [markdown]
# Read data

# %%
with open("../jinja2/data/16.json", "r") as inputFile:
    data = json.load(inputFile)
NormData=pd.json_normalize(data['users'])
NormData.head()
# Out:
#                      id  \
# 0  U1663263134503-13414
# 1   U1663446898395-9517
# 2   U1663446985735-5204
# 3  U1663447449455-12376
# 4  U1663448380431-12109
#
#    LandingPage.LandingPageData.submittimeFinalReceiveResultsAgreement  \
# 0                                                NaN
# 1                                                NaN
# 2                                                4.0
# 3                                                4.0
# 4                                               10.0
#
#   LandingPage.submittime  \
# 0                    NaN
# 1                    NaN
# 2       2022-9-18 1:6:28
# 3      2022-9-18 1:14:11
# 4      2022-9-18 1:29:49
#
#    GlobalConsent.GlobalConsentData.submittimetaskConsentAgreement  \
# 0                                                NaN
# 1                                                NaN
# 2                                               18.0
# 3                                                4.0
# 4                                               23.0
#
#   GlobalConsent.GlobalConsentData.taskConsentAgreement  \
# 0                                                NaN
# 1                                                NaN
# 2   من موارد فوق را خواندم و بر اساس آن، رضایت آگ...
# 3   من موارد فوق را خواندم و بر اساس آن، رضایت آگ...
# 4   من موارد فوق را خواندم و بر اساس آن، رضایت آگ...
#
#   GlobalConsent.submittime  \
# 0                      NaN
# 1                      NaN
# 2         2022-9-18 1:6:44
# 3        2022-9-18 1:14:13
# 4        2022-9-18 1:30:11
#
#    GlobalConsent.timestampsforoptionchange.taskConsentAgreement.start  \
# 0                                                NaN
# 1                                                NaN
# 2                                       1.663447e+12
# 3                                       1.663447e+12
# 4                                       1.663448e+12
#
#    GlobalConsent.timestampsforoptionchange.taskConsentAgreement.startsurvey  \
# 0                                                NaN
# 1                                                NaN
# 2                                       1.663447e+12
# 3                                       1.663447e+12
# 4                                       1.663448e+12
#
#    GlobalConsent.timestampsforoptionchange.taskConsentAgreement.end  \
# 0                                                NaN
# 1                                                NaN
# 2                                       1.663447e+12
# 3                                       1.663447e+12
# 4                                       1.663448e+12
#
#    otherPIIDisClosure.otherPIIDisClosureData.submittimeotherPIIDisClosureSurvey  \
# 0                                                NaN
# 1                                                NaN
# 2                                               26.0
# 3                                               12.0
# 4                                               83.0
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   otherPIIDisClosure.otherPIIDisClosureData.otherPIIDisClosureMultiText02.otherPhoneNumber02  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    otherPIIDisClosure.otherPIIDisClosureData.otherPIIDisClosureMultiText03.otherName03  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    otherPIIDisClosure.otherPIIDisClosureData.otherPIIDisClosureMultiText03.otherFamilyName03  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    otherPIIDisClosure.otherPIIDisClosureData.otherPIIDisClosureMultiText03.otherPhoneNumber03  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    otherPIIDisClosure.otherPIIDisClosureData.otherPIIDisClosureMultiText04.otherName04  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   otherPIIDisClosure.otherPIIDisClosureData.otherPIIDisClosureMultiText04.otherFamilyName04  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    otherPIIDisClosure.otherPIIDisClosureData.otherPIIDisClosureMultiText04.otherPhoneNumber04  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   willingnessToPayOthers.timestampsforoptionchange.TPBQuestionnaireNormDesc.startsurvey  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Assessment.Assessment.timestampsforoptionchange.FinalReceiveResultsAgreement.start  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Assessment.Assessment.timestampsforoptionchange.FinalReceiveResultsAgreement.startsurvey
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 326 columns]

# %%
#  ! #######################

# DFNotRepeatedNoneFilled =
# print(type(DFNotRepeatedNoneFilled))

# for LabelsUsualSuspect in LabelsUsualSuspects:
#     experiment  = DFNotRepeatedNoneFilled.loc[:, LabelsUsualSuspect]
# experiment  = DFNotRepeatedNoneFilled.loc[:, LabelsUsualSuspects]
# experimentCopy = DFNotRepeatedNoneFilled.loc[:, LabelsUsualSuspects]
# LabelsUsualSuspects = data['users']['id']
LabelsUsualSuspects = data.copy()

#  ! #######################

# print(LabelsUsualSuspects.head())
# [a['LandingPage']['LandingPageData']['submittimeFinalReceiveResultsAgreement'] for a in LabelsUsualSuspects['users'][0]]

# experiment.to_excel("../jinja2/data/experiment16.xlsx")
LabelsUsualSuspects['users'][3]['LandingPage']
# Out:
# {'LandingPageData': {'submittimeFinalReceiveResultsAgreement': 4},
#  'submittime': '2022-9-18 1:14:11'}

# %%
#  ! #######################

# DFNotRepeatedNoneFilled =
# print(type(DFNotRepeatedNoneFilled))

# for LabelsUsualSuspect in LabelsUsualSuspects:
#     experiment  = DFNotRepeatedNoneFilled.loc[:, LabelsUsualSuspect]
# experiment  = DFNotRepeatedNoneFilled.loc[:, LabelsUsualSuspects]
# experimentCopy = DFNotRepeatedNoneFilled.loc[:, LabelsUsualSuspects]
# LabelsUsualSuspects = data['users']['id']
# LabelsUsualSuspects = data.copy()

#  ! #######################

# print(LabelsUsualSuspects.head())
# [a['LandingPage']['LandingPageData']['submittimeFinalReceiveResultsAgreement'] for a in LabelsUsualSuspects['users'][0]]

# experiment.to_excel("../jinja2/data/experiment16.xlsx")
LabelsUsualSuspects['users'][3]['LandingPage']['submittime']
# Out:
# '2022-9-18 1:14:11'

# %%
#  ! #######################

# DFNotRepeatedNoneFilled =
# print(type(DFNotRepeatedNoneFilled))

# for LabelsUsualSuspect in LabelsUsualSuspects:
#     experiment  = DFNotRepeatedNoneFilled.loc[:, LabelsUsualSuspect]
# experiment  = DFNotRepeatedNoneFilled.loc[:, LabelsUsualSuspects]
# experimentCopy = DFNotRepeatedNoneFilled.loc[:, LabelsUsualSuspects]
# LabelsUsualSuspects = data['users']['id']
LabelsUsualSuspects = pd.DataFrame(data.copy()['users'])
ExpData = LabelsUsualSuspects.copy()
ExpData = [json.loads(i) for i in pd.DataFrame(
    ExpData.copy()['LandingPage']).dropna().index()]
# (ExpData.copy()['LandingPage'])
#  ! #######################

# print(LabelsUsualSuspects.head())
# [a['LandingPage']['submittime'] for a in LabelsUsualSuspects['users'] if a['LandingPage'].notnone()]

# experiment.to_excel("../jinja2/data/experiment16.xlsx")
# LabelsUsualSuspects['users'][3]['LandingPage']['submittime']
ExpData.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/master/pj/gitprojects/thesis/latex/tehran-thesis-master/jinja2/newJSON.ipynb Cell 6 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/home/master/pj/gitprojects/thesis/latex/tehran-thesis-master/jinja2/newJSON.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a> LabelsUsualSuspects = pd.DataFrame(data.copy()['users'])
#      <a href='vscode-notebook-cell:/home/master/pj/gitprojects/thesis/latex/tehran-thesis-master/jinja2/newJSON.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a> ExpData = LabelsUsualSuspects.copy()
# ---> <a href='vscode-notebook-cell:/home/master/pj/gitprojects/thesis/latex/tehran-thesis-master/jinja2/newJSON.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a> ExpData = [json.loads(i) for i in pd.DataFrame(
#      <a href='vscode-notebook-cell:/home/master/pj/gitprojects/thesis/latex/tehran-thesis-master/jinja2/newJSON.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a>     ExpData.copy()['LandingPage']).dropna().index()]
#      <a href='vscode-notebook-cell:/home/master/pj/gitprojects/thesis/latex/tehran-thesis-master/jinja2/newJSON.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a> # (ExpData.copy()['LandingPage'])
#      <a href='vscode-notebook-cell:/home/master/pj/gitprojects/thesis/latex/tehran-thesis-master/jinja2/newJSON.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a> #  ! #######################
#      <a href='vscode-notebook-cell:/home/master/pj/gitprojects/thesis/latex/tehran-thesis-master/jinja2/newJSON.ipynb#X10sZmlsZQ%3D%3D?line=16'>17</a>
#    (...)
#      <a href='vscode-notebook-cell:/home/master/pj/gitprojects/thesis/latex/tehran-thesis-master/jinja2/newJSON.ipynb#X10sZmlsZQ%3D%3D?line=20'>21</a> # experiment.to_excel("../jinja2/data/experiment16.xlsx")
#      <a href='vscode-notebook-cell:/home/master/pj/gitprojects/thesis/latex/tehran-thesis-master/jinja2/newJSON.ipynb#X10sZmlsZQ%3D%3D?line=21'>22</a> # LabelsUsualSuspects['users'][3]['LandingPage']['submittime']
#      <a href='vscode-notebook-cell:/home/master/pj/gitprojects/thesis/latex/tehran-thesis-master/jinja2/newJSON.ipynb#X10sZmlsZQ%3D%3D?line=22'>23</a> ExpData.head()
#
# TypeError: 'Int64Index' object is not callable
